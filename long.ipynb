# %% [markdown]
# <a href="https://colab.research.google.com/github/Kartel7/DASIO-Model-0.25-Sirius-case-/blob/main/long.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# На входе есть множество характеристик, расчитанных по изображениям специальной камеры, снимающей небосвод. Наша задача: предсказать значение приходящей длинноволновой радиации по имеющемуся датасету с характеристиками этих изображений. Подробнее: https://github.com/MKrinitskiy/Sirius-AI4Climate-2024/blob/main/DASIO-dataset-description.md

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Входные данные

df = pd.read_csv("/content/drive/MyDrive/dataset_25perc.csv", sep=',')
df.sample(5)
# Out:
#                                photo_name       photo_datetime  CM3up[W/m2]  \
# 56598   img-2015-06-22T16-47-55devID1.jpg  2015-06-22 16:47:55   201.101272
# 227146  img-2021-08-09T03-40-33devID2.jpg  2021-08-09 03:40:33    50.986091
# 199022  img-2017-03-13T12-17-28devID1.jpg  2017-03-13 12:17:28   797.676442
# 174115  img-2021-09-06T10-22-54devID2.jpg  2021-09-06 10:22:54   335.484686
# 199221  img-2017-03-15T08-44-54devID2.jpg  2017-03-15 08:44:54   570.703046
#
#         CG3up[W/m2]  CM3down[W/m2]  CG3down[W/m2]   radiation_datetime  \
# 56598    -14.878841      27.957057       3.127400  2015-06-22 16:47:54
# 227146   -18.385319      13.457295      -2.274472  2021-08-09 03:40:39
# 199022  -112.965465     200.722194      52.691945  2017-03-13 12:17:30
# 174115   -53.923951      94.106298      -2.748321  2021-09-06 10:22:54
# 199221  -125.569833     167.647574       6.254799  2017-03-15 08:44:59
#
#           feature0     feature1  feature2  feature3  feature4  feature5  \
# 56598    96.613462   372.516081     129.0      16.0 -0.903729 -0.529233
# 227146   84.341517   309.026389     127.0      13.0 -0.751449 -0.637338
# 199022   78.187741   928.725902     255.0       9.0  1.412215  4.825255
# 174115  115.811298  1303.941165     255.0      19.0  0.130039 -0.050075
# 199221   86.904623  1679.733354     255.0      16.0  1.511056  2.990504
#
#         feature6  feature7  ...  feature152  feature153  feature154  \
# 56598        1.0       8.0  ...    0.401495    0.418936    0.432700
# 227146       1.0       7.0  ...    0.352575    0.363742    0.372648
# 199022      12.0      17.0  ...    0.296739    0.311263    0.325487
# 174115       5.0      13.0  ...    0.425689    0.442871    0.460519
# 199221      15.0      22.0  ...    0.311395    0.330173    0.352539
#
#         feature155  feature156  feature157  feature158  feature159  \
# 56598     0.444000    0.455566    0.464206    0.476669    0.486706
# 227146    0.380691    0.391458    0.405051    0.423728    0.440345
# 199022    0.339080    0.356229    0.382284    0.417910    0.473078
# 174115    0.480469    0.503191    0.540679    0.590462    0.658558
# 199221    0.376067    0.398467    0.426849    0.480321    0.560547
#
#         feature160  feature161      date-hour                datetime_UTC  \
# 56598     0.492688    0.499867  2015-06-22-16  2015-06-22 16:47:55.536289
# 227146    0.465869    0.501396  2021-08-09-03  2021-08-09 03:40:33.163472
# 199022    0.521666    0.757428  2017-03-13-12  2017-03-13 12:17:27.812283
# 174115    0.746001    0.888967  2021-09-06-10  2021-09-06 10:22:54.060943
# 199221    0.704216    0.942606  2017-03-15-08  2017-03-15 08:44:53.797709
#
#               lat        lon  sun_altitude
# 56598   59.505299 -26.339182     42.147750
# 227146  64.703408  40.527580     16.073947
# 199022  35.824744  14.855322     48.338637
# 174115  56.006069  12.666925     39.479589
# 199221  37.610801   7.169363     33.350300
#
# [5 rows x 174 columns]

# %%
# Удаляем имена изображений
df = df.drop('photo_name', axis = 1)

# %%
# Дату в datetime формат
df['photo_datetime'] = pd.to_datetime(df['photo_datetime'])

# %%
df['days'] = df['photo_datetime'].dt.day
df['year_date'] = df['photo_datetime'].dt.year

# %%
# Вычисляем разницу в секундах между значениями в столбце 'photo_datetime' и начальной датой
df['date_seconds'] = (df['photo_datetime'] - df['photo_datetime'].min()).dt.total_seconds()

# %%
df = df.sort_values("date_seconds", axis=0)

# %%
df.index=range(0,len(df))

# %%
# Переводим линейное представление времени в цикличное (т.е. 31 декабря и 1 января следующего года будут близки несмотря на разницу в год)
df['dateyear'] = (df['photo_datetime'].dt.dayofyear - 1) / 365
df['cos'] = np.cos(df['dateyear'] * 2 * np.pi)
df['sin'] = np.sin(df['dateyear'] * 2 * np.pi)

# %%
# Вывод важных полей
df[['CM3up[W/m2]', 'CG3up[W/m2]', 'sin', 'cos', 'lat', 'lon', 'sun_altitude']]
# Out:
#         CM3up[W/m2]  CG3up[W/m2]       sin       cos        lat        lon  \
# 0        143.102225   -88.135807 -0.967938 -0.251190  66.584686 -29.280270
# 1        143.102225   -88.135807 -0.967938 -0.251190  66.584686 -29.280270
# 2        159.023532   -87.377650 -0.967938 -0.251190  66.586937 -29.289083
# 3        159.023532   -87.377650 -0.967938 -0.251190  66.586937 -29.289083
# 4        160.824156   -86.903802 -0.967938 -0.251190  66.588477 -29.294644
# ...             ...          ...       ...       ...        ...        ...
# 260428   182.242105   -52.312866 -0.903356 -0.428892  55.545024  12.705800
# 260429   181.483948   -52.123327 -0.903356 -0.428892  55.544092  12.705888
# 260430   180.915329   -52.028557 -0.903356 -0.428892  55.542581  12.706041
# 260431   180.725790   -52.028557 -0.903356 -0.428892  55.542266  12.706072
# 260432   180.631020   -51.839018 -0.903356 -0.428892  55.541646  12.706124
#
#         sun_altitude
# 0          14.488320
# 1          14.488320
# 2          14.655731
# 3          14.655731
# 4          14.739936
# ...              ...
# 260428     30.696305
# 260429     30.642495
# 260430     30.552547
# 260431     30.534529
# 260432     30.498458
#
# [260433 rows x 7 columns]

# %%
df
# Out:
#             photo_datetime  CM3up[W/m2]  CG3up[W/m2]  CM3down[W/m2]  \
# 0      2014-09-17 10:02:43   143.102225   -88.135807      36.391559
# 1      2014-09-17 10:02:44   143.102225   -88.135807      36.391559
# 2      2014-09-17 10:04:43   159.023532   -87.377650      44.162673
# 3      2014-09-17 10:04:44   159.023532   -87.377650      44.162673
# 4      2014-09-17 10:05:45   160.824156   -86.903802      44.636522
# ...                    ...          ...          ...            ...
# 260428 2021-09-06 13:53:28   182.242105   -52.312866      60.463059
# 260429 2021-09-06 13:53:58   181.483948   -52.123327      60.083981
# 260430 2021-09-06 13:54:48   180.915329   -52.028557      59.894441
# 260431 2021-09-06 13:54:58   180.725790   -52.028557      59.894441
# 260432 2021-09-06 13:55:18   180.631020   -51.839018      59.894441
#
#         CG3down[W/m2]   radiation_datetime    feature0     feature1  feature2  \
# 0            0.473848  2014-09-17 10:02:44   96.890459  1671.656306     255.0
# 1            0.473848  2014-09-17 10:02:44  108.081154  1784.724755     255.0
# 2            0.379079  2014-09-17 10:04:44   98.760528  1723.527972     255.0
# 3            0.379079  2014-09-17 10:04:44  109.894952  1814.364325     255.0
# 4            0.568618  2014-09-17 10:05:44  111.069528  1877.696783     255.0
# ...               ...                  ...         ...          ...       ...
# 260428      -3.601248  2021-09-06 13:53:34   93.887588   205.434115     135.0
# 260429      -3.506478  2021-09-06 13:54:04   93.766927   205.713884     131.0
# 260430      -3.601248  2021-09-06 13:54:54   93.492497   209.849320     133.0
# 260431      -3.601248  2021-09-06 13:55:04   94.056191   205.642272     144.0
# 260432      -3.696018  2021-09-06 13:55:24   94.009298   207.837473     143.0
#
#         feature3  feature4  feature5  feature6  feature7  feature8  ...  \
# 0           31.0  1.121827  2.437911       7.0      16.0      20.0  ...
# 1           43.0  0.813509  1.466658       3.0      14.0      19.0  ...
# 2           31.0  1.083457  2.204960       8.0      16.0      21.0  ...
# 3           42.0  0.787298  1.310879       5.0      15.0      20.0  ...
# 4           44.0  0.787653  1.232283       6.0      15.0      20.0  ...
# ...          ...       ...       ...       ...       ...       ...  ...
# 260428      11.0 -1.053254 -0.293065       1.0       7.0      14.0  ...
# 260429      18.0 -1.053141 -0.291374       1.0       7.0      14.0  ...
# 260430      18.0 -1.044951 -0.300195       1.0       7.0      13.0  ...
# 260431      31.0 -1.050130 -0.200994       0.0       7.0      12.0  ...
# 260432      28.0 -1.045499 -0.204053       0.0       6.0      12.0  ...
#
#         feature158  feature159  feature160  feature161      date-hour  \
# 0         0.493691    0.543301    0.702826    0.973412  2014-09-17-10
# 1         0.507907    0.558590    0.708413    0.973412  2014-09-17-10
# 2         0.506745    0.558490    0.713127    0.973412  2014-09-17-10
# 3         0.521335    0.576076    0.719611    0.973412  2014-09-17-10
# 4         0.525156    0.585410    0.734166    0.973412  2014-09-17-10
# ...            ...         ...         ...         ...            ...
# 260428    0.437321    0.449086    0.464208    0.484048  2021-09-06-13
# 260429    0.438618    0.449086    0.462812    0.481821  2021-09-06-13
# 260430    0.439382    0.449551    0.461316    0.480127  2021-09-06-13
# 260431    0.442174    0.452676    0.464772    0.484613  2021-09-06-13
# 260432    0.442838    0.452676    0.465005    0.484613  2021-09-06-13
#
#                       datetime_UTC        lat        lon  sun_altitude  days  \
# 0       2014-09-17 10:02:43.303133  66.584686 -29.280270     14.488320    17
# 1       2014-09-17 10:02:43.303133  66.584686 -29.280270     14.488320    17
# 2       2014-09-17 10:04:43.319997  66.586937 -29.289083     14.655731    17
# 3       2014-09-17 10:04:43.319997  66.586937 -29.289083     14.655731    17
# 4       2014-09-17 10:05:44.623504  66.588477 -29.294644     14.739936    17
# ...                            ...        ...        ...           ...   ...
# 260428  2021-09-06 13:53:28.099585  55.545024  12.705800     30.696305     6
# 260429  2021-09-06 13:53:58.111208  55.544092  12.705888     30.642495     6
# 260430  2021-09-06 13:54:48.125231  55.542581  12.706041     30.552547     6
# 260431  2021-09-06 13:54:58.128647  55.542266  12.706072     30.534529     6
# 260432  2021-09-06 13:55:18.135837  55.541646  12.706124     30.498458     6
#
#         year_date  date_seconds  dateyear       cos       sin
# 0            2014           0.0  0.709589 -0.251190 -0.967938
# 1            2014           1.0  0.709589 -0.251190 -0.967938
# 2            2014         120.0  0.709589 -0.251190 -0.967938
# 3            2014         121.0  0.709589 -0.251190 -0.967938
# 4            2014         182.0  0.709589 -0.251190 -0.967938
# ...           ...           ...       ...       ...       ...
# 260428       2021   219988245.0  0.679452 -0.428892 -0.903356
# 260429       2021   219988275.0  0.679452 -0.428892 -0.903356
# 260430       2021   219988325.0  0.679452 -0.428892 -0.903356
# 260431       2021   219988335.0  0.679452 -0.428892 -0.903356
# 260432       2021   219988355.0  0.679452 -0.428892 -0.903356
#
# [260433 rows x 179 columns]

# %%
# Поскольку время уже переведено в значения cos и sin, удаляем все признаки, где упоминается date
df = df.loc[:, ~df.columns.str.contains('date')]

# %%
df_corr = df.corr()['CG3up[W/m2]'].sort_values()
print(df_corr)
# Out:
# feature4      -0.864836
# feature31     -0.836236
# feature139    -0.799586
# feature132    -0.794878
# feature80     -0.794497
#                  ...
# CG3up[W/m2]    1.000000
# feature114          NaN
# feature115          NaN
# feature116          NaN
# feature117          NaN
# Name: CG3up[W/m2], Length: 172, dtype: float64

# %%
df.head()
# Out:
#    CM3up[W/m2]  CG3up[W/m2]  CM3down[W/m2]  CG3down[W/m2]    feature0  \
# 0   143.102225   -88.135807      36.391559       0.473848   96.890459
# 1   143.102225   -88.135807      36.391559       0.473848  108.081154
# 2   159.023532   -87.377650      44.162673       0.379079   98.760528
# 3   159.023532   -87.377650      44.162673       0.379079  109.894952
# 4   160.824156   -86.903802      44.636522       0.568618  111.069528
#
#       feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0  1671.656306     255.0      31.0  1.121827  2.437911       7.0      16.0
# 1  1784.724755     255.0      43.0  0.813509  1.466658       3.0      14.0
# 2  1723.527972     255.0      31.0  1.083457  2.204960       8.0      16.0
# 3  1814.364325     255.0      42.0  0.787298  1.310879       5.0      15.0
# 4  1877.696783     255.0      44.0  0.787653  1.232283       6.0      15.0
#
#    feature8  feature9  feature10  ...  feature153  feature154  feature155  \
# 0      20.0      26.0       51.0  ...    0.385274    0.397735    0.411894
# 1      19.0      24.0       52.0  ...    0.397970    0.410332    0.424855
# 2      21.0      27.0       53.0  ...    0.389096    0.401093    0.415949
# 3      20.0      25.0       55.0  ...    0.401559    0.413756    0.428647
# 4      20.0      25.0       56.0  ...    0.403900    0.416449    0.430970
#
#    feature156  feature157  feature158  feature159  feature160  feature161  \
# 0    0.430139    0.457923    0.493691    0.543301    0.702826    0.973412
# 1    0.441672    0.469360    0.507907    0.558590    0.708413    0.973412
# 2    0.435069    0.464571    0.506745    0.558490    0.713127    0.973412
# 3    0.446060    0.475736    0.521335    0.576076    0.719611    0.973412
# 4    0.448153    0.478827    0.525156    0.585410    0.734166    0.973412
#
#          lat        lon  sun_altitude  days      cos       sin
# 0  66.584686 -29.280270     14.488320    17 -0.25119 -0.967938
# 1  66.584686 -29.280270     14.488320    17 -0.25119 -0.967938
# 2  66.586937 -29.289083     14.655731    17 -0.25119 -0.967938
# 3  66.586937 -29.289083     14.655731    17 -0.25119 -0.967938
# 4  66.588477 -29.294644     14.739936    17 -0.25119 -0.967938
#
# [5 rows x 172 columns]

# %% [markdown]
# ## Задача регрессии

# %%
X = df.drop(['CM3up[W/m2]','CG3up[W/m2]','CM3down[W/m2]','CG3down[W/m2]'], axis = 1)
y = df['CG3up[W/m2]']

# CG3up[W/m2] --> Приходящая длинноволновая радиация

# %%
# Разбиваем данные на выборки так, чтобы одни дни были в тренировочной выборке, другие - в тестовой

from sklearn.model_selection import GroupShuffleSplit
gss = GroupShuffleSplit(n_splits=2, test_size=0.1, random_state=38)

for train_index, test_index in gss.split(X, y, groups=df['days']):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
# Проверка пересекающихся в рамках дня данных

X_test["days"].unique()
# Out:
# array([21, 15, 27,  9], dtype=int32)

# %%
X_train["days"].unique()

# Данные не пересекаются
# Out:
# array([17, 18, 19, 20, 22, 23, 24, 25, 12, 13, 14, 16, 26, 28, 29, 30,  1,
#         2,  3,  4,  5,  6,  7,  8, 11, 31, 10], dtype=int32)

# %%
pip install -r '/content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt'
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# Requirement already satisfied: joblib==1.4.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: xgboost==2.1.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: catboost==1.2.7 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (1.2.7)
# Requirement already satisfied: scikit-learn==1.5.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: scipy==1.14.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 5)) (1.14.0)
# Collecting numpy (from xgboost==2.1.1->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 2))
#   Using cached numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost==2.1.1->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 2)) (2.21.5)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (3.10.0)
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.1->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost==1.2.7->-r /content/drive/MyDrive/Colab Notebooks/Sirius project/requirements.txt (line 3)) (9.1.2)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# Installing collected packages: numpy
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_percentage_error
#from sklearn.model_selection import RandomizedSearchCV -- параметры подбирались через RandomizedSearchCV и вручную

# %%
from xgboost import XGBRegressor

# %%
# Задаем оптимальные параметры, подобранные перебором вручную
etr = XGBRegressor(random_state=35, max_depth=7, learning_rate=0.05, gamma=0.2, n_estimators=1000,colsample_bytree=0.6 )
model = etr

# %%
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.6, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.2, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=35, ...)

# %%
preds = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error

# %%
mean_absolute_percentage_error(preds,y_test)
# Out:
# 0.31441031450435364

# %%
r2_score(preds,y_test)
# Out:
# 0.8588887921750898

# %%
mean_absolute_error(preds,y_test)
# Out:
# 8.705714824725158

# %%
root_mean_squared_error(preds,y_test)
# Out:
# 12.779780260678477

# %%
preds_series = pd.Series(preds)
preds_series.index = y_test.index
preds_series.name = 'CG3up_predicted'
preds_series
# Out:
# 664      -19.258133
# 665      -17.598831
# 666      -17.302557
# 667      -15.449218
# 668      -19.053596
#             ...
# 241589    -6.290244
# 241590   -10.287186
# 241591    -6.789811
# 241592    -9.410515
# 241593    -9.682592
# Name: CG3up_predicted, Length: 31758, dtype: float32

# %%
y_test
# Out:
# 664      -29.473372
# 665      -36.012480
# 666      -33.643238
# 667      -33.643238
# 668      -30.231530
#             ...
# 241589    -5.970490
# 241590    -5.875720
# 241591    -5.780951
# 241592    -5.970490
# 241593    -5.875720
# Name: CG3up[W/m2], Length: 31758, dtype: float64

# %%
results = pd.merge(y_test, preds_series, left_index=True, right_index=True, how='outer')

# %%
# Сравнение реальных и предсказанных значений радиации
results.sample(10)
# Out:
#         CG3up[W/m2]  CG3up_predicted
# 31897    -39.708498       -53.991409
# 75198    -53.450103       -62.929775
# 86299    -31.558305       -41.296215
# 79265    -69.276640       -58.640255
# 32403    -87.851498       -75.621193
# 58029    -40.371886       -51.440121
# 224192   -16.016077       -13.412304
# 58115    -39.234650       -30.521265
# 96204    -74.109894       -56.382122
# 210311    -6.065260        -7.422730

# %% [markdown]
# # Сохранение/использование модели и итоговая оценка

# %%
from joblib import dump, load
dump(etr, 'longRmodel.joblib')
# Out:
# ['longRmodel.joblib']

# %%
CG3up = load('longRmodel.joblib')

# %%
import time

start_time = time.time()
num_samples = len(X_test)
preds = CG3up.predict(X_test)

total_time = time.time() - start_time
average_time = total_time / num_samples

print(f"Общее время выполнения: {total_time:.6f} секунд")
print(f"Среднее время выполнения: {average_time:.6f} секунд")
# Out:
# Общее время выполнения: 1.371862 секунд
# Среднее время выполнения: 0.000043 секунд

# %%
mae = mean_absolute_error(preds,y_test)
rmse = root_mean_squared_error(preds, y_test)
print('mae:', mae, 'rmse:', rmse)
# Out:
# mae: 8.705714824725158 rmse: 12.779780260678477

# %%
std = df.describe().loc['std', 'CG3up[W/m2]']
print('std:', std)
# Out:
# std: 37.96773051574533

# %% [markdown]
# **Ошибка в целом адекватна относительно стандартного отклонения во входных данных**
